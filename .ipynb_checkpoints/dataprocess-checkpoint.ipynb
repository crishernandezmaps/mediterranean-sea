# %%
import pandas as pd
from geopandas import GeoDataFrame
import shapely.geometry
from shapely.geometry import Point

# %%
df = pd.read_csv('data/missingMigrants.csv')
med = df.loc[(df['Region of Incident'] == 'Mediterranean') & df['Information Reliability'].isin(['Verified'])]
med.head()
# Out:
#     Web ID Region of Incident      Reported Date  Reported Year  \
# 2    44086      Mediterranean   January 09, 2018           2018
# 5    44080      Mediterranean   January 07, 2018           2018
# 6    44079      Mediterranean   January 06, 2018           2018
# 7    44078      Mediterranean   January 05, 2018           2018
# 21   44071      Mediterranean  December 22, 2017           2017
#
#    Reported Month  Number Dead  Number Missing  Total Dead and Missing  \
# 2             Jan          NaN           100.0                     100
# 5             Jan          2.0            10.0                      12
# 6             Jan          8.0            56.0                      64
# 7             Jan          4.0             NaN                       4
# 21            Dec          1.0             NaN                       1
#
#     Number of survivors  Number of Female  Number of Male  Number of Children  \
# 2                  16.0               NaN             NaN                 NaN
# 5                 270.0               2.0             NaN                 NaN
# 6                  86.0               6.0             2.0                 5.0
# 7                   4.0               NaN             NaN                 NaN
# 21                  NaN               NaN             NaN                 NaN
#
#        Cause of death                               Location Description  \
# 2   Presumed drowning                   Off the coast of Al Khums, Libya
# 5   Presumed drowning                   Off the coast of Garabuli, Libya
# 6             Unknown        Unspecified location off the coast of Libya
# 7   Presumed drowning  Near Tanger-Med cargo port, 40km east of Tangi...
# 21  Presumed drowning                                Near Tripoli, Libya
#
#                       Information Source                          Location  \
# 2   IOM Libya, Reuters, AFP, Libyan Navy  33.461246171967, 14.630447728125
# 5                              IOM Libya  32.983002330562, 13.768852058594
# 6   IOM Italy, SOS Méditerranée, MSF Sea  34.078380455797, 13.268242596875
# 7                    Salvamento Marítimo  35.880538323659, -5.519505224414
# 21                             IOM Libya  32.926409826220, 13.113060712109
#
#    Information Reliability          Migrant Route  \
# 2                 Verified  Central Mediterranean
# 5                 Verified  Central Mediterranean
# 6                 Verified  Central Mediterranean
# 7                 Verified  Western Mediterranean
# 21                Verified  Central Mediterranean
#
#                                                   URL  \
# 2   http://bit.ly/2FnDv26, http://reut.rs/2CJiA7F,...
# 5                               http://bit.ly/2Enoaxc
# 6   http://bbc.in/2Ej8fzR, http://bit.ly/2D7iXdi, ...
# 7        http://bit.ly/2qG7miM, http://bit.ly/2mcXFDW
# 21                                                NaN
#
#    UNSD Geographical Grouping
# 2               Uncategorized
# 5               Uncategorized
# 6               Uncategorized
# 7               Uncategorized
# 21              Uncategorized

# %%
x = lambda row: float(row.split(",")[0])
y = lambda row: float(row.split(",")[1])

# %%
med['latitude'] = med['Location'].map(x)

# %%
med['longitude'] = med['Location'].map(y)

# %%
med.head(3)
# Out:
#    Web ID Region of Incident     Reported Date  Reported Year Reported Month  \
# 2   44086      Mediterranean  January 09, 2018           2018            Jan
# 5   44080      Mediterranean  January 07, 2018           2018            Jan
# 6   44079      Mediterranean  January 06, 2018           2018            Jan
#
#    Number Dead  Number Missing  Total Dead and Missing  Number of survivors  \
# 2          NaN           100.0                     100                 16.0
# 5          2.0            10.0                      12                270.0
# 6          8.0            56.0                      64                 86.0
#
#    Number of Female    ...                             Location Description  \
# 2               NaN    ...                 Off the coast of Al Khums, Libya
# 5               2.0    ...                 Off the coast of Garabuli, Libya
# 6               6.0    ...      Unspecified location off the coast of Libya
#
#                      Information Source                          Location  \
# 2  IOM Libya, Reuters, AFP, Libyan Navy  33.461246171967, 14.630447728125
# 5                             IOM Libya  32.983002330562, 13.768852058594
# 6  IOM Italy, SOS Méditerranée, MSF Sea  34.078380455797, 13.268242596875
#
#   Information Reliability          Migrant Route  \
# 2                Verified  Central Mediterranean
# 5                Verified  Central Mediterranean
# 6                Verified  Central Mediterranean
#
#                                                  URL  \
# 2  http://bit.ly/2FnDv26, http://reut.rs/2CJiA7F,...
# 5                              http://bit.ly/2Enoaxc
# 6  http://bbc.in/2Ej8fzR, http://bit.ly/2D7iXdi, ...
#
#   UNSD Geographical Grouping                                 geometry  \
# 2              Uncategorized  POINT (14.630447728125 33.461246171967)
# 5              Uncategorized  POINT (13.768852058594 32.983002330562)
# 6              Uncategorized  POINT (13.268242596875 34.078380455797)
#
#     latitude  longitude
# 2  33.461246  14.630448
# 5  32.983002  13.768852
# 6  34.078380  13.268243
#
# [3 rows x 23 columns]

# %%
geometry = [Point(xy) for xy in zip((med.longitude).astype(float), (med.latitude).astype(float))]
med = med.drop(['latitude', 'longitude'], axis=1)
crs = {'init': 'epsg:4326'}
gdf = GeoDataFrame(med, crs=crs, geometry=geometry)

# %%
gdf.to_file("mediterraneum.geojson", driver='GeoJSON')
# Out:
# ---------------------------------------------------------------------------
# CPLE_NotSupportedError                    Traceback (most recent call last)
# fiona/ogrext.pyx in fiona.ogrext.WritingSession.start()
#
# fiona/_err.pyx in fiona._err.exc_wrap_pointer()
#
# CPLE_NotSupportedError: GeoJSON driver doesn't support creating a layer on a read-only datasource
#
# During handling of the above exception, another exception occurred:
#
# DriverIOError                             Traceback (most recent call last)
# <ipython-input-15-46820e1d6cac> in <module>()
# ----> 1 gdf.to_file("mediterraneum.geojson", driver='GeoJSON')
#
# /usr/local/lib/python3.6/site-packages/geopandas/geodataframe.py in to_file(self, filename, driver, schema, **kwargs)
#     363         """
#     364         from geopandas.io.file import to_file
# --> 365         to_file(self, filename, driver, schema, **kwargs)
#     366
#     367     def to_crs(self, crs=None, epsg=None, inplace=False):
#
# /usr/local/lib/python3.6/site-packages/geopandas/io/file.py in to_file(df, filename, driver, schema, **kwargs)
#      62     with fiona.drivers():
#      63         with fiona.open(filename, 'w', driver=driver, crs=df.crs,
# ---> 64                         schema=schema, **kwargs) as colxn:
#      65             for feature in df.iterfeatures():
#      66                 colxn.write(feature)
#
# /usr/local/lib/python3.6/site-packages/fiona/__init__.py in open(path, mode, driver, schema, crs, encoding, layer, vfs, enabled_drivers, crs_wkt)
#     173         c = Collection(path, mode, crs=crs, driver=driver, schema=this_schema,
#     174                        encoding=encoding, layer=layer, vsi=vsi, archive=archive,
# --> 175                        enabled_drivers=enabled_drivers, crs_wkt=crs_wkt)
#     176     else:
#     177         raise ValueError(
#
# /usr/local/lib/python3.6/site-packages/fiona/collection.py in __init__(self, path, mode, driver, schema, crs, encoding, layer, vsi, archive, enabled_drivers, crs_wkt, **kwargs)
#     154             elif self.mode in ('a', 'w'):
#     155                 self.session = WritingSession()
# --> 156                 self.session.start(self, **kwargs)
#     157         except IOError:
#     158             self.session = None
#
# fiona/ogrext.pyx in fiona.ogrext.WritingSession.start()
#
# DriverIOError: GeoJSON driver doesn't support creating a layer on a read-only datasource

# %%
! ls

# %%
med.head()
